# %% [markdown]
# <div>
# <img src="https://i.ibb.co/v3CvVz9/udd-short.png" width="150"/>
#     <br>
#     <strong>Universidad del Desarrollo</strong><br>
#     <em>Magíster en Data Science</em><br>
#     <em>Profesor: Víctor Navarro Aránguiz</em><br>
#
# </div>
#
# # Python para Data Science: Proyecto final
# *15 de Julio de 2024*
#
# **Fecha de Entrega**: 04 de Agosto de 2024
#
# **Objetivos:**
#   - Aplicar los conceptos aprendidos en clases.
#   - Realizar el análisis de un dataset de su preferencia.
#   - Familiarizarse con el manejo de versiones a través de Git.
#
# **Puntaje Total:** 4 Puntos
#
# **Nombre Estudiante(s)**: `Giuseppe Lavarello`

# %% [markdown]
# ### Creación de Variables
# ##### Importe de Paquetes

# %%
# Para manipulación de data 
import numpy as np
import pandas as pd

# Para visualización de data
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Carga de Datos

# %%
# Cargar la versión intermedia del dataset

df0 = pd.read_csv("..\\data\\interim\\wine_inter01.csv")

# %%
# Crear una muestra de los valores
df0.sample(5)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1374            7.8              0.17         0.24            7.70      0.047
# 3900            5.8              0.33         0.28            1.20      0.031
# 1089            7.5              0.23         0.32            9.20      0.038
# 359             7.2              0.40         0.22            1.50      0.058
# 1040            7.9              0.40         0.37            5.85      0.033
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1374                 21.0                  98.0  0.99510  3.01       0.36
# 3900                 33.0                  97.0  0.99126  3.39       0.58
# 1089                 54.0                 191.0  0.99660  3.04       0.56
# 359                  16.0                 151.0  0.99380  3.07       0.57
# 1040                 27.0                  93.0  0.99200  3.16       0.54
#
#       alcohol  quality
# 1374      9.6        6
# 3900     10.9        6
# 1089      9.7        6
# 359       9.2        4
# 1040     12.6        7

# %% [markdown]
# ##### Creacion de variables
# - Total acidity

# %%
# Se crea la feature `total_acidity` en base a la suma de las características de acidez
df0['total_acidity'] = df0["fixed_acidity"] + df0["volatile_acidity"]

# %%
df0.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            13.0      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.0              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            6.2              0.32         0.22             7.0      0.045
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   0.9978  3.01       0.45
# 1                 15.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality  total_acidity
# 0      8.8        6           7.27
# 1      9.5        6           6.60
# 2     10.1        6           8.28
# 3      9.9        6           7.43
# 4      9.6        6           6.52

# %%
df0[["fixed_acidity","volatile_acidity","total_acidity","quality"]].corr()
# Out:
#                   fixed_acidity  volatile_acidity  total_acidity   quality
# fixed_acidity          1.000000         -0.032528       0.994316 -0.096797
# volatile_acidity      -0.032528          1.000000       0.074074 -0.162276
# total_acidity          0.994316          0.074074       1.000000 -0.113870
# quality               -0.096797         -0.162276      -0.113870  1.000000

# %% [markdown]
# **Desición** Se puede ver que la variable `total_acidity` no precenta una "mayor" (como en mas lejos de 0) correlacion con la variable `quality` por lo que sera descartada pues no impulza el objetivo de crear una regresión

# %%
df0.drop(columns="total_acidity",inplace=True)

# %% [markdown]
# - Fixed sulfur dioxide

# %%
df0['fixed_sulfur_dioxide'] = df0['total_sulfur_dioxide'] - df0['free_sulfur_dioxide']

# %%
df0.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            13.0      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.0              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            6.2              0.32         0.22             7.0      0.045
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   0.9978  3.01       0.45
# 1                 15.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality  fixed_sulfur_dioxide
# 0      8.8        6                 125.0
# 1      9.5        6                 117.0
# 2     10.1        6                  67.0
# 3      9.9        6                 139.0
# 4      9.6        6                 106.0

# %%
df0[["free_sulfur_dioxide","total_sulfur_dioxide","fixed_sulfur_dioxide","quality"]].corr()
# Out:
#                       free_sulfur_dioxide  total_sulfur_dioxide  \
# free_sulfur_dioxide              1.000000              0.615941
# total_sulfur_dioxide             0.615941              1.000000
# fixed_sulfur_dioxide             0.282764              0.929808
# quality                          0.024497             -0.200620
#
#                       fixed_sulfur_dioxide   quality
# free_sulfur_dioxide               0.282764  0.024497
# total_sulfur_dioxide              0.929808 -0.200620
# fixed_sulfur_dioxide              1.000000 -0.255713
# quality                          -0.255713  1.000000

# %% [markdown]
# **Decisión**: Aquí se ve que la nueva variable `fixed_sulfur_dioxide` presenta una mayor correlación con la variable `quality` que las dos variables que la forman, por lo que la mantendremos. Esto nos permitira utilizarla en vez de las 2 anteriores a la hora de crear la regresión disminuyendo la dimensionalidad total del problema.
